# %% [markdown]
# Score and Predict Large Datasets
# ================================

# %% [markdown]
# Sometimes you'll train on a smaller dataset that fits in memory, but need to predict or score for a much larger (possibly larger than memory) dataset. Perhaps your [learning curve](http://scikit-learn.org/stable/modules/learning_curve.html) has leveled off, or you only have labels for a subset of the data.
#
# In this situation, you can use [ParallelPostFit](http://ml.dask.org/modules/generated/dask_ml.wrappers.ParallelPostFit.html) to parallelize and distribute the scoring or prediction steps.

# %%
from dask.distributed import Client, progress


# Assuming you've already set up your cluster and client
client = Client('localhost:8786')

client
# Out:
# <Client: 'tcp://10.249.14.40:8786' processes=12 threads=3072, memory=5.58 TiB>
# 2024-11-12 16:27:21,288 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client

# %%
import numpy as np
import dask.array as da
from sklearn.datasets import make_classification

# %%
from dask.distributed import PipInstall
plugin = PipInstall(packages=["dask-ml"], pip_options=["--upgrade"])

# %% [markdown]
# We'll generate a small random dataset with scikit-learn.

# %%
X_train, y_train = make_classification(
    n_features=2, n_redundant=0, n_informative=2,
    random_state=1, n_clusters_per_class=1, n_samples=1000)
X_train[:5]
# Out:
# array([[ 1.53682958, -1.39869399],
#        [ 1.36917601, -0.63734411],
#        [ 0.50231787, -0.45910529],
#        [ 1.83319262, -1.29808229],
#        [ 1.04235568,  1.12152929]])

# %% [markdown]
# And we'll clone that dataset many times with `dask.array`. `X_large` and `y_large` represent our larger than memory dataset.

# %%
# Scale up: increase N, the number of times we replicate the data.
N = 100
X_large = da.concatenate([da.from_array(X_train, chunks=X_train.shape)
                          for _ in range(N)])
y_large = da.concatenate([da.from_array(y_train, chunks=y_train.shape)
                          for _ in range(N)])
X_large
# Out:
# dask.array<concatenate, shape=(100000, 2), dtype=float64, chunksize=(1000, 2), chunktype=numpy.ndarray>

# %% [markdown]
# Since our training dataset fits in memory, we can use a scikit-learn estimator as the actual estimator fit during traning.
# But we know that we'll want to predict for a large dataset, so we'll wrap the scikit-learn estimator with `ParallelPostFit`.

# %%
from sklearn.linear_model import LogisticRegressionCV
from dask_ml.wrappers import ParallelPostFit

# %%
clf = ParallelPostFit(LogisticRegressionCV(cv=3), scoring="r2")

# %% [markdown]
# See the note in the `dask-ml`'s documentation about when and why a `scoring` parameter is needed: https://ml.dask.org/modules/generated/dask_ml.wrappers.ParallelPostFit.html#dask_ml.wrappers.ParallelPostFit.

# %% [markdown]
# Now we'll call `clf.fit`. Dask-ML does nothing here, so this step can only use datasets that fit in memory.

# %%
clf.fit(X_train, y_train)
# Out:
# ParallelPostFit(estimator=LogisticRegressionCV(cv=3), scoring='r2')

# %% [markdown]
# Now that training is done, we'll turn to predicting for the full (larger than memory) dataset.

# %%
y_pred = clf.predict(X_large)
y_pred
# Out:
# dask.array<_predict, shape=(100000,), dtype=int64, chunksize=(1000,), chunktype=numpy.ndarray>

# %% [markdown]
# y_pred is Dask arary. Workers can write the predicted values to a shared file system, without ever having to collect the data on a single machine.
#
# Or we can check the models score on the entire large dataset. The computation will be done in parallel, and no single machine will have to hold all the data.

# %%
clf.score(X_large, y_large)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/distributed/scheduler.py:4659, in update_graph()
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/distributed/protocol/serialize.py:439, in deserialize()
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/distributed/protocol/serialize.py:101, in pickle_loads()
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/distributed/protocol/pickle.py:94, in loads()
#
# ModuleNotFoundError: No module named 'dask_ml'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 clf.score(X_large, y_large)
#
# File ~/miniforge3/envs/nersc2/lib/python3.11/site-packages/dask_ml/wrappers.py:294, in ParallelPostFit.score(self, X, y, compute)
#     292     else:
#     293         scorer = get_scorer(scoring, compute=compute)
# --> 294     return scorer(self, X, y)
#     295 else:
#     296     return self._postfit_estimator.score(X, y)
#
# File ~/miniforge3/envs/nersc2/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:279, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     276 if sample_weight is not None:
#     277     _kwargs["sample_weight"] = sample_weight
# --> 279 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File ~/miniforge3/envs/nersc2/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:376, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     371 y_pred = method_caller(
#     372     estimator, response_method.__name__, X, pos_label=pos_label
#     373 )
#     375 scoring_kwargs = {**self._kwargs, **kwargs}
# --> 376 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File ~/miniforge3/envs/nersc2/lib/python3.11/site-packages/dask_ml/metrics/regression.py:178, in r2_score(y_true, y_pred, sample_weight, multioutput, compute)
#     176 result = output_scores.mean(axis=0)
#     177 if compute:
# --> 178     result = result.compute()
#     179 return result
#
# File ~/miniforge3/envs/nersc2/lib/python3.11/site-packages/dask/base.py:342, in DaskMethodsMixin.compute(self, **kwargs)
#     318 def compute(self, **kwargs):
#     319     """Compute this dask collection
#     320
#     321     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     340     dask.compute
#     341     """
# --> 342     (result,) = compute(self, traverse=False, **kwargs)
#     343     return result
#
# File ~/miniforge3/envs/nersc2/lib/python3.11/site-packages/dask/base.py:628, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     625     postcomputes.append(x.__dask_postcompute__())
#     627 with shorten_traceback():
# --> 628     results = schedule(dsk, keys, **kwargs)
#     630 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniforge3/envs/nersc2/lib/python3.11/site-packages/distributed/client.py:2243, in Client._gather(self, futures, errors, direct, local_worker)
#    2241         exc = CancelledError(key)
#    2242     else:
# -> 2243         raise exception.with_traceback(traceback)
#    2244     raise exc
#    2245 if errors == "skip":
#
# RuntimeError: Error during deserialization of the task graph. This frequently
# occurs if the Scheduler and Client have different environments.
# For more information, see
# https://docs.dask.org/en/stable/deployment-considerations.html#consistent-software-environments
